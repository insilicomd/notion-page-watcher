# %%
from notion_page_watcher import main

# %%
# 오늘 기준 어제 업데이터 검색 및 알림
main(reciver_email_list=["recipient@example.com"], now=None)

# 2025년 12월 17일 기준 12월 16일 업데이트 검색
main(reciver_email_list=["recipient@example.com"], now="20251217")
